# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson
from scipy.stats import binom

# %% [markdown]
# * POISSON DISTRIBUTION

# %% [markdown]
# #Generate random samples from a poisson distribution
# samples =  poisson.rvs(mu=3,size=1000)

# %%
#Plot histogram of the samples
plt.hist(samples,bins=np.arange(0,max(samples) + 1)-0.5,density=True,edgecolor='black',alpha=0.7)
# Out:
# (array([0.04714142, 0.1444333 , 0.2116349 , 0.26278837, 0.16449348,
#         0.10130391, 0.0441324 , 0.02006018, 0.00401204]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5]),
#  <BarContainer object of 9 artists>)

# %%
#Plot the PMF
k_values = np.arange(0,max(samples) + 1)
pmf_values = poisson.pmf(k_values,mu=3)
plt.vlines(k_values,0,pmf_values,colors='red',lw=2,label='Poisson PMF')
plt.hist(samples,bins=np.arange(0,max(samples) + 1)-0.5,density=True,edgecolor='black',alpha=0.7)
plt.title(f'Poisson Distribution (λ={3})')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %% [markdown]
# * BINOMIAL DISTRIBUTION

# %%
#Parameters
n= 10             #No of trials
p = 0.5           #Probability of success
#Generate random samples from a binomial distribution
samples = binom.rvs(n=n ,p=p, size=1000)

# %%
#Plot histogram of the samples
plt.hist(samples,bins=np.arange(0, n+2)-0.5,density=True,edgecolor='black',alpha=0.7)
# Out:
# (array([0.002, 0.017, 0.051, 0.11 , 0.168, 0.244, 0.223, 0.124, 0.051,
#         0.01 , 0.   ]),
#  array([-0.5,  0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5,
#         10.5]),
#  <BarContainer object of 11 artists>)

# %%
#Plot the PMF
k_values = np.arange(0 , n+1)
pmf_values = binom.pmf(k_values, n=n , p=p)
plt.vlines(k_values,0,pmf_values,colors='red',lw=2,label='Binomial PMF')
plt.hist(samples,bins=np.arange(0,n+2)-0.5,density=True,edgecolor='black',alpha=0.7)
plt.title(f'Binomail Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.legend()
plt.show()

# %% [markdown]
# * NORMAL DISTRIBUTION
